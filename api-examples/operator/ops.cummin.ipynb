# %% [markdown]
# ## mindspore.ops.cummin(input, axis) -〉 Tensor
# - 输入：
#     * input必须为mindspore的tensor。
#     * axis必须为int类型。
# - 返回：元组类型，包含两个tensor。

# %%
import numpy as np
import mindspore as ms
import torch
import jax.lax as jlx

input = np.array([[3, 4, 6, 10], [1, 6, 7, 9], [4, 3, 8, 7], [1, 3, 7, 9]])

y1 = ms.ops.cummin(ms.tensor(input), axis = 0)
y2 = torch.cummin(torch.tensor(input), dim = 0)
y3 = jlx.cummin(input, axis = 0)
print ('mindspore output ->\n',y1)
print('\n')
print ('torch     output ->\n',y2)
print('\n')
print ('jax       output ->\n',y3)
# Out:
# mindspore output ->
#  [Tensor(shape=[4, 4], dtype=Int64, value=
# [[ 3,  4,  6, 10],
#  [ 1,  4,  6,  9],
#  [ 1,  3,  6,  7],
#  [ 1,  3,  6,  7]]), Tensor(shape=[4, 4], dtype=Int32, value=
# [[0, 0, 0, 0],
#  [1, 0, 0, 1],
#  [1, 2, 0, 2],
#  [3, 3, 0, 2]])]
#
#
# torch     output ->
#  torch.return_types.cummin(
# values=tensor([[ 3,  4,  6, 10],
#         [ 1,  4,  6,  9],
#         [ 1,  3,  6,  7],
#         [ 1,  3,  6,  7]]),
# indices=tensor([[0, 0, 0, 0],
#         [1, 0, 0, 1],
#         [1, 2, 0, 2],
#         [3, 3, 0, 2]]))
#
#
# jax       output ->
#  [[ 3  4  6 10]
#  [ 1  4  6  9]
#  [ 1  3  6  7]
#  [ 1  3  6  7]]

# %% [markdown]
# 1、ms的输出value在最后面，建议提前。
# 2、jax的输出为array, 不会输出最大值的索引。

# %%
out2 = (torch.tensor([0]),torch.tensor([0]))

torch.cummin(torch.tensor(input), dim = 0, out = out2)
print ('torch     output ->\n',out2)
# Out:
# torch     output ->
#  (tensor([[ 3,  4,  6, 10],
#         [ 1,  4,  6,  9],
#         [ 1,  3,  6,  7],
#         [ 1,  3,  6,  7]]), tensor([[0, 0, 0, 0],
#         [1, 0, 0, 1],
#         [1, 2, 0, 2],
#         [3, 3, 0, 2]]))
# /var/folders/wy/5yzfdb6x7pvfxh89zcmf_w780000gn/T/ipykernel_65447/1583831531.py:3: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [4, 4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_68u_j54pu8/croot/pytorch-select_1717607460029/work/aten/src/ATen/native/Resize.cpp:35.)
#   torch.cummin(torch.tensor(input), dim = 0, out = out2)

# %% [markdown]
# torch还提供了出参的方式，ms未支持。

# %%
y1 = ms.ops.cummin(input, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y1 = ms.ops.cummin(input, axis = 0)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/function/math_func.py:5587, in cummin(input, axis)
#    5585 cummin_op = _get_cache_prim(Cummin)(axis=0)
#    5586 if axis == 0:
# -> 5587     out1, out2 = cummin_op(input)
#    5588 else:
#    5589     x_shape = shape_(input)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/auto_generate/gen_ops_prim.py:4085, in Cummin.__call__(self, input)
#    4084 def __call__(self, input):
# -> 4085       return super().__call__(input, self.axis)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/primitive.py:405, in Primitive.__call__(self, *args)
#     403 if should_elim:
#     404     return output
# --> 405 return _run_op(self, self.name, args)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/primitive.py:1022, in _run_op(obj, op_name, args)
#    1020 """Single op execution function supported by ge in PyNative mode."""
#    1021 if not _RunOpHook.current:
# -> 1022     stub = _pynative_executor.run_op_async(obj, op_name, args)
#    1023     return _convert_stub(stub)
#    1024 return _RunOpHook.current.hook(obj, args)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/common/api.py:1423, in _PyNativeExecutor.run_op_async(self, *args)
#    1413 def run_op_async(self, *args):
#    1414     """
#    1415     Run single op async.
#    1416
#    (...)
#    1421         StubNode, result of run op.
#    1422     """
# -> 1423     return self._executor.run_op_async(*args)
#
# TypeError: Failed calling Cummin with "Cummin(axis=int)(input=<class 'numpy.ndarray'>)".
# The valid calling should be:
# "Cummin(axis=<int>)(input=<Tensor>)".
#
# ----------------------------------------------------
# - C++ Call Stack: (For framework developers)
# ----------------------------------------------------
# mindspore/ccsrc/pipeline/pynative/pynative_utils.cc:1294 PrintTypeCastError

# %%
y2 = torch.cummin(input, dim = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y2 = torch.cummin(input, dim = 0)
#
# TypeError: cummin() received an invalid combination of arguments - got (numpy.ndarray, dim=int), but expected one of:
#  * (Tensor input, int dim, *, tuple of Tensors out)
#  * (Tensor input, name dim, *, tuple of Tensors out)

# %%
y3 = jlx.cummin(torch.tensor(input), axis = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y3 = jlx.cummin(torch.tensor(input), axis = 0)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:2299, in cummin(operand, axis, reverse)
#    2297 def cummin(operand: Array, axis: int = 0, reverse: bool = False) -> Array:
#    2298   """Computes a cumulative minimum along `axis`."""
# -> 2299   return cummin_p.bind(operand, axis=int(axis), reverse=bool(reverse))
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:416, in Primitive.bind(self, *args, **params)
#     413 def bind(self, *args, **params):
#     414   assert (not config.enable_checks.value or
#     415           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 416   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 8 frame]
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/dtypes.py:347, in issubdtype(a, b)
#     330 """Returns True if first argument is a typecode lower/equal in type hierarchy.
#     331
#     332 This is like :func:`numpy.issubdtype`, but can handle dtype extensions such as
#     333 :obj:`jax.dtypes.bfloat16` and `jax.dtypes.prng_key`.
#     334 """
#     335 # Main departures from np.issubdtype are:
#     336 # - "extended" dtypes (like prng key types) are not normal numpy dtypes, so we
#     337 #   need to handle them specifically. However, their scalar types do conform to
#    (...)
#     344 # unhashable (e.g. custom objects with a dtype attribute). The following check is
#     345 # fast and covers the majority of calls to this function within JAX library code.
#     346 return _issubdtype_cached(
# --> 347   a if isinstance(a, (type, np.dtype, ExtendedDType)) else np.dtype(a),  # type: ignore[arg-type]
#     348   b if isinstance(b, (type, np.dtype, ExtendedDType)) else np.dtype(b),  # type: ignore[arg-type]
#     349 )
#
# TypeError: Cannot interpret 'torch.int64' as a data type

# %% [markdown]
# 当输入类型不正确时，报错信息torch最简洁明确。建议ms优化。
