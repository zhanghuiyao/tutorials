# %% [markdown]
# ## mindspore.ops.div(input, other, *, rounding_mode=None) -〉 Tensor
# - 输入：
#     * input/other必须为mindspore的tensor，数据类型为int或bool。
#     * rounding_mode为字符串类型，可选值有：None 、 "floor" 和 "trunc"。
# - 返回：mindspore的tensor。

# %%
import numpy as np
import mindspore as ms
import torch
import jax.lax as jlx

input = np.array([ 0.3810,  1.2774, -0.2972, -0.3719,  0.4637])
other = np.array(0.5)

y1 = ms.ops.div(ms.tensor(input), ms.tensor(other))
y2 = torch.div(torch.tensor(input), torch.tensor(other))
y3 = jlx.div(input, other)
print ('mindspore output ->\n',y1)
print ('torch     output ->\n',y2)
print ('jax       output ->\n',y3)
# Out:
# mindspore output ->
#  [ 0.762   2.5548 -0.5944 -0.7438  0.9274]
# torch     output ->
#  tensor([ 0.7620,  2.5548, -0.5944, -0.7438,  0.9274], dtype=torch.float64)
# jax       output ->
#  [ 0.762   2.5548 -0.5944 -0.7438  0.9274]

# %% [markdown]
# ms和jax不会输出类型。

# %%
input = np.array([[-0.3711, -1.9353, -0.4605, -0.2917],
                  [ 0.1815, -1.0111,  0.9805, -1.5923],
                  [ 0.1062,  1.4581,  0.7759, -1.2344],
                  [-0.1830, -0.0313,  1.1908, -1.4757]])
other = np.array([ 0.8032,  0.2930, -0.8113, -0.2308])

y1 = ms.ops.div(ms.tensor(input), ms.tensor(other), rounding_mode='trunc')
y2 = torch.div(torch.tensor(input), torch.tensor(other), rounding_mode='trunc')
print ('mindspore output ->\n',y1)
print ('torch     output ->\n',y2)
# Out:
# mindspore output ->
#  [[-0. -6.  0.  1.]
#  [ 0. -3. -1.  6.]
#  [ 0.  4. -0.  5.]
#  [-0. -0. -1.  6.]]
# torch     output ->
#  tensor([[-0., -6.,  0.,  1.],
#         [ 0., -3., -1.,  6.],
#         [ 0.,  4., -0.,  5.],
#         [-0., -0., -1.,  6.]], dtype=torch.float64)

# %%
y3 = jlx.div(input, other)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y3 = jlx.div(input, other)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/lax/lax.py:437, in div(x, y)
#     430 def div(x: ArrayLike, y: ArrayLike) -> Array:
#     431   r"""Elementwise division: :math:`x \over y`.
#     432
#     433   Integer division overflow
#     434   (division by zero or signed division of INT_SMIN with -1)
#     435   produces an implementation defined value.
#     436   """
# --> 437   return div_p.bind(x, y)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:416, in Primitive.bind(self, *args, **params)
#     413 def bind(self, *args, **params):
#     414   assert (not config.enable_checks.value or
#     415           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 416   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 18 frame]
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/lax/lax.py:1690, in broadcasting_shape_rule(name, *avals)
#    1688 if len({len(shape) for shape in shapes}) != 1:
#    1689   msg = '{}: arrays must have same number of dimensions, got {}.'
# -> 1690   raise TypeError(msg.format(name, ', '.join(map(str, map(tuple, shapes)))))
#    1691 # TODO(mattjj): de-duplicate with _try_broadcast_shapes
#    1692 result_shape = []
#
# TypeError: div: arrays must have same number of dimensions, got (4, 4), (4,).

# %% [markdown]
# 1、当输入为多维数组时, jax不接受input和other shape不一致。
# 2、jax不支持向上向下取整。

# %%
out2 = torch.tensor([])

torch.div(torch.tensor(input), torch.tensor(other), rounding_mode='trunc', out = out2)
print ('torch     output ->\n',out2)
# Out:
# torch     output ->
#  tensor([[-0., -6.,  0.,  1.],
#         [ 0., -3., -1.,  6.],
#         [ 0.,  4., -0.,  5.],
#         [-0., -0., -1.,  6.]])

# %% [markdown]
# torch还提供了出参的方式，ms未支持。

# %%
y1 = ms.ops.div(input,other)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wy/5yzfdb6x7pvfxh89zcmf_w780000gn/T/ipykernel_66951/491695102.py in ?()
# ----> 1 y1 = ms.ops.div(input,other)
#
# /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/function/math_func.py in ?(input, other, rounding_mode)
#     781         raise ValueError("For ops.div, rounding_mode value should be None, 'floor' or 'trunc'.")
#     782     if rounding_mode:
#     783         output = tensor_divmod_(input, other, rounding_mode)
#     784     else:
# --> 785         output = tensor_div_(input, other)
#     786     return output
#
# /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/auto_generate/gen_ops_prim.py in ?(self, x, y)
#    4330     def __call__(self, x, y):
# -> 4331           return _convert_stub(pyboost_div(self, [x, y]))
#
# TypeError: Failed calling Div with "Div()(x=<class 'numpy.ndarray'>, y=<class 'numpy.ndarray'>)".
# The valid calling should be:
# "Div()(x=<Number, Tensor>, y=<Number, Tensor>)".
#
# ----------------------------------------------------
# - C++ Call Stack: (For framework developers)
# ----------------------------------------------------
# mindspore/ccsrc/pipeline/pynative/pynative_utils.cc:1294 PrintTypeCastError

# %%
y2 = torch.div(input, other)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y2 = torch.div(input, other)
#
# TypeError: div(): argument 'input' (position 1) must be Tensor, not numpy.ndarray

# %%
y3 = jlx.diag(torch.tensor(input,other))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y3 = jlx.diag(torch.tensor(input,other))
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/deprecations.py:55, in deprecation_getattr.<locals>.getattr(name)
#      53   warnings.warn(message, DeprecationWarning, stacklevel=2)
#      54   return fn
# ---> 55 raise AttributeError(f"module {module!r} has no attribute {name!r}")
#
# AttributeError: module 'jax.lax' has no attribute 'diag'

# %% [markdown]
# 当输入类型不正确时，报错信息torch最简洁明确。建议ms优化。
